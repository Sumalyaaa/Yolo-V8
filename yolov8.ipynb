# %%
# !pip install ultralytics
# !pip install roboflow

# %%
# !nvidia-smi

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()

# %%
import ultralytics
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uTXN3M2kLc69Uoi69uqW")
project = rf.workspace("brad-dwyer").project("pklot-1tros")
version = project.version(4)
dataset = version.download("yolov8")

# %%
# !ls -la /kaggle/working/PKLot-4/data.yaml

# %%
# !yolo task=detect mode=train model=/kaggle/working/yolov8n.pt \
  data=/kaggle/working/PKLot-4/data.yaml \
  imgsz=640 batch=32 epochs=20 optimizer=AdamW lr0=0.01 lrf=0.1

# %%
# !yolo task=detect mode=train model=/kaggle/working/yolov8n.pt \
  data=/kaggle/working/PKLot-4/data.yaml \
  imgsz=640 batch=32 epochs=25 optimizer=AdamW lr0=0.01 lrf=0.1

# %%
# !yolo task=detect mode=train model=/kaggle/working/yolov8n.pt \
  data=/kaggle/working/PKLot-4/data.yaml \
  imgsz=640 batch=32 epochs=15 optimizer=SGD lr0=0.01 lrf=0.1

# %%
# Run inference and save predictions on every test image
# !yolo task=detect mode=predict \
    model=/kaggle/working/runs/detect/train/weights/best.pt \
    source=/kaggle/working/PKLot-4/test/images \
    imgsz=640 conf=0.3 iou=0.65 save=True

# %%
# !yolo train \
  model=yolov8m.pt \
  data=/kaggle/working/PKLot-4/data.yaml \
  device=0,1 \
  imgsz=832 batch=32 epochs=100 \
  optimizer=AdamW lr0=0.003 lrf=0.1 weight_decay=0.01 \
  box=4.5 cls=1.0 dfl=1.5 \
  hsv_h=0.02 hsv_s=0.6 hsv_v=0.5 \
  degrees=2 translate=0.06 scale=0.4 \
  mosaic=1.0 close_mosaic=15 fliplr=0.2 erasing=0.1 \
  cache=disk workers=4

# %%
# !yolo val \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  data=/kaggle/working/PKLot-4/data.yaml split=test \
  imgsz=960 conf=0.30 iou=0.70 max_det=200

# %%
# !yolo val \
    model=/kaggle/working/runs/detect/train3/weights/best.pt \
    data=/kaggle/working/PKLot-4/data.yaml \
    split=test \
    imgsz=960 conf=0.25 iou=0.65

# %%
# !yolo predict model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/working/PKLot-4/test/images imgsz=960 conf=0.30 iou=0.70 save=True

# %%
# !yolo predict model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/parkvideo1/park1.mp4 imgsz=960 conf=0.30 iou=0.70 save=True

# %%
# !yolo predict model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest1/car.jpg imgsz=960 conf=0.30 iou=0.70 save=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest2/cartest2.webp imgsz=1280 conf=0.15 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest3/cartest3.jpg imgsz=1280 conf=0.3 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest44/cartest4.jpg \
  imgsz=1280 conf=0.20 iou=0.70 \
  agnostic_nms=True max_det=1000 line_thickness=1 \
  augment=True save=True save_txt=True save_conf=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest44/cartest4.jpg \
  imgsz=1536 conf=0.05 iou=0.45 \
  max_det=3000 line_thickness=1 \
  save=True save_txt=True save_conf=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest5/cartest7.webp imgsz=1280 conf=0.3 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest7/CT10.jpg imgsz=640 conf=0.3 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest7/CT11.jpg imgsz=1280 conf=0.3 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest7/CT9.jpg imgsz=1280 conf=0.3 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest8/CT12.jpg imgsz=1280 conf=0.3 iou=0.65 augment=True

# %%
# !yolo predict \
  model=/kaggle/working/runs/detect/train3/weights/best.pt \
  source=/kaggle/input/cartest8/CT13.jpg imgsz=1280 conf=0.3 iou=0.65 augment=True
